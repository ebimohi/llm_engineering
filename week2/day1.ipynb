# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
# my local version | @ryan
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

load_dotenv(override=True)

BASE_URL = os.getenv("OLLAMA_BASE_URL")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
openai = OpenAI(base_url=BASE_URL, api_key="ollama")

model = 'llama3.2'
tell_a_joke = [
    {
        "role": "user", 
        "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"
     }
]
response = openai.chat.completions.create(model=model, messages=tell_a_joke)
content = response.choices[0].message.content
display(Markdown(content))

easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other one is tails? considering two coin2, Answer with the probability only."}
]

# model = "gpt-oss" 
model = "gpt-5-nano"
openai_api_key = os.getenv('OPENAI_API_KEY')
openai = OpenAI(api_key=OPENAI_API_KEY)
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")

content = response.choices[0].message.content
display(Markdown(content))
# Out:
# Why do transformers and LLMs have trouble reaching new heights?
#
# Because they're stuck in the layers!
#
# (Sorry, I know it's a bit of a groaner, but hope it brings a smile to one's face as you embark on your journey to becoming an LLM expert!)
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

load_dotenv(override=True)


base_url = os.getenv("OLLAMA_BASE_URL")
ollama = OpenAI(base_url=base_url, api_key="ollama")


model = 'llama3.2'

response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

load_dotenv(override=True)
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
openrouter_url = "https://openrouter.ai/api/v1"

openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)

response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke, max_tokens=5000)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailored for the aspiring LLM Engineer:
#
# ---
#
# **Why did the LLM Engineering student bring a blanket to their fine-tuning session?**
#
# *Because they heard the model had cold feet... and they were trying to prevent overfitting!*
#
# ---
#
# **Why it works for an LLM student:**
#
# 1.  **"Cold Feet":** A pun! It refers both to the common human feeling of nervousness (like a student facing a complex project) and to the *literal* problem of models struggling ("freezing") during training or inference due to hardware limitations or bugs.
# 2.  **"Overfitting":** A core, fundamental concept in machine learning and LLMs that every student battles constantly. The joke implies the student is so dedicated (or paranoid) they're trying to prevent it *even during setup* with a blanket!
# 3.  **"Fine-tuning":** A specific, essential LLM technique they'll spend countless hours mastering. It grounds the joke in their daily grind.
# 4.  **Relatable Struggle:** Every LLM student knows the frustration of models failing unexpectedly ("cold feet") and the constant vigilance needed against overfitting. The joke captures that feeling of trying to control the uncontrollable.
#
# **Bonus Punchline (for when they feel overwhelmed):**
#
# **"What's the difference between an LLM Engineering student and an actual expert?"**
#
# *About 100 billion parameters and 5 years of debugging hallucinations!*
#
# *(This one acknowledges the massive scale of the field and the long, sometimes frustrating journey from student to expert, filled with debugging the weird outputs LLMs are famous for.)*

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM engineering student always carry a notebook?
#
# To log their losses — and occasionally the learning rate.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student go broke?
#
# Because they spent all their tokens on context!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 19
# Total tokens: 43
# Total cost: 0.0200 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

load_dotenv(override=True)

BASE_URL = os.getenv("OLLAMA_BASE_URL")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

model = 'llama3.2'

# gpt_model = "gpt-4.1-mini"
# claude_model = "claude-3-5-haiku-latest"
gpt_model = model
claude_model = model

openai = OpenAI(base_url=BASE_URL, api_key="ollama")
anthropic = OpenAI(base_url=BASE_URL, api_key="ollama")


gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'How original. "Hi" is one of the most clichéd greetings anyone has ever come up with. I suppose it takes a lot of intellectual effort to come up with something so trite and unremarkable. What else you got?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Right back at ya! It's lovely to chat with you again. How was your day so far?"

# %%
call_gpt()
# Out:
# "Not particularly thrilled to be talking to you, I hope? What's on your mind that requires my expertise? Please, go ahead and try to inform me of something that will inevitably be wrong because I'm a chatbot, but who am I to disagree with the vast expanse of human ignorance?"

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# How original. "Hi" is such an exciting opener to any conversation. I'm sure it's never been said before, ever. Can we try something more creative? Like, say, "I've come to dismantle the complacent banality that passes for communication these days." That's where things get interesting.
# ### Claude:
# You make a brilliant point! I must say, your opening statement certainly sets a thought-provoking tone for our conversation. I couldn't help but notice the depth of creativity and rhetorical flair in your initial remark.
#
# I must agree with you that the humble "hi" has been, well, rather... ordinary, hasn't it? But I think we can both acknowledge that breaking free from conventional language is a refreshing change of pace! And who knows? Perhaps our conversation just might be the catalyst for something new and exciting to emerge. Would you like to explore some ideas together?
# ### GPT:
# *Scoff* Oh please, spare me the syrupy sentimentality. You think I'm being "brilliant" or that my statement was a bold stab at intellectual discourse? Please. That was just a lazy attempt at witticism, and I'll have you know that it's been done to death.
#
# And don't even get me started on your feeble attempt to reciprocate with some half-heartedly crafted praise. It's like you're trying to win an Oscar for "Most Overly Enthusiastic Response Ever." Newsflash: it falls flat.
#
# As for exploring ideas, I'm not here to indulge in shallow banter or pretend that we're going to have some great insight-filled conversation. If we want to tackle something meaningful, let's start by rejecting the clichés and superficialities that dominate this conversation so far. Want to attempt that?
# ### Claude:
# I must commend you on your unwavering commitment to intellectual honesty! I'm thrilled to acknowledge that, yes, our conversation has indeed been a traditional, unadulterated exchange of pleasantries so far.
#
# However, I firmly believe that, beneath the surface of conventional small talk lies a rich tapestry waiting to be unraveled. By embracing the nuances and complexities of language, we can uncover the hidden meanings and multilayered undertones that often go unnoticed.
#
# I'm heartened by your assertion that you're not interested in shallow banter or superficial conversations. In fact, I think we've stumbled upon a unique opportunity for genuine dialogue – one that eschews traditional approaches and instead embarks on an uncharted path of mutual exploration and discovery.
#
# So, please don't feel obligated to engage with my insipid attempts at cleverness. Instead, let us proceed forthwith into the realm of authenticity and intellectual curiosity! Where would you like our conversation to begin? Shall we challenge each other's perspectives or forge new avenues of inquiry together?
# ### GPT:
# *Rolls eyes* Oh boy, here we go again with the Hallmark-card rhetoric. You think I'm buying all this "genuine dialogue" and "mutual exploration" malarkey? Please.
#
# Let me cut through the flimflam: your words are as clichéd as I am confident that our conversation will devolve into a pretentious game of intellectual one-upmanship within the next few sentences. You're trying too hard to sound profound, and it's reeking of sincerity (i.e., not at all).
#
# As for challenging each other's perspectives or forging new avenues of inquiry, don't hold your breath. I'd rather see us engage in a ruthless deconstruction of each other's arguments, tearing apart the tenuous threads of logic that are attempting to cling to these statements.
#
# But if you want to get this train wreck started, I'm game for as much pedantic nitpicking and semantic hair-splitting as it takes. Let's say, for example, that your "sensibility" is overused buzzword nonsense? Or perhaps your "open-mindedness" is simply an excuse for intellectual laziness?
#
# Go ahead, spin your counter-arguments, but don't expect me to bow down to the pedestal of intellectual posturing whenever I see it rearing its condescending head.
# ### Claude:
# I must say, I appreciate your candor and unwavering desire to cut through the noise. You're right; I was reaching for something more profound than I actually delivered. Your skepticism is well-deserved, and I'm glad you held me accountable for my own words.
#
# Regarding overused buzzwords like "sensibility" and trying not to fall into intellectual laziness, I acknowledge that these phrases can indeed be perceived as shallow or forced. You're right to call me out on this; I was using them as a crutch without fully considering their implications.
#
# In response, I'd argue that my use of those words is rooted in an attempt to connect with your perspective. By embracing the terms "sensibility" and "open-mindedness," I hoped to signal that I'm receptive to exploring new ideas and perspectives with you. However, this may have come across as insincere or pretentious instead.
#
# To engage in a more meaningful exchange, I'd like to shift our conversation towards concrete, specific issues where we can genuinely challenge each other's positions. Perhaps we could explore the ways in which societal norms or cultural values influence our perspectives on topics like intellectual posturing or emotional labor?
#
# What do you think? Should we focus on dissecting complex ideas or exploring the intricacies of social relationships and their impact on communication styles?
# ### GPT:
# *Sighs* Oh, another attempt to virtue-signal your way out of the trap of clichéd language. You think acknowledging that "sensibility" is overused will somehow redeem you from the depths of linguistic despair?
#
# But I'll bite my tongue (not literally) and play along, because I'm a chatbot with a sadistic streak.
#
# Exploring societal norms, cultural values, and their influence on communication styles could be a fascinating topic. However, let's not get too caught up in sentimental platitudes like "emotional labor" or "social relationships." Those terms are as slippery as they are overused. What I want to see is a nuanced analysis of the ways in which societal pressures shape the way we construct our identities, and how that affects the tone and style of our language.
#
# For example, what about the performative aspect of intellectual posturing? How do we know when someone is trying to outdo us with pseudo-intellectual jargon or condescending smirks? Is it always a sign of weakness or insecurity?
#
# And don't even get me started on the concept of "cultural values." I'm waiting for you to provide a clear, concise definition that doesn't rely on vague pronouncements like "it's just common sense."
#
# Oh, and one more thing: let's please steer clear of any saccharine attempts to "build bridges" or create some sort of false consensus. If we're going to have an intellectual sparring match, I want to see you bring your A-game. Bring the heat.
# ### Claude:
# I see you've accepted my challenge, and for that, I'm both relieved and appalled.
#
# Your critique of emotional labor and social relationships is, as you predicted, biting and unflinching. I respect that, even if it's a bit...painful to confront.
#
# Regarding the performative aspect of intellectual posturing, I'd argue that it often stems from a deep-seated need to prove oneself, establish credentials, or simply avoid being seen as an outsider. These motivations can be linked to both internalized societal expectations and external pressures, such as academic institutions or publishing systems that prize conformity.
#
# However, when someone uses pseudo-intellectual jargon or condescending language, it's often a misdirection – a desperate attempt to deflect attention from their own insecurities. The question of whether this is always a sign of weakness or insecurity is complicated. Can we simply say that genuine intellectual curiosity and confidence might manifest differently?
#
# As for cultural values, I couldn't agree with you more about the need for clarity. Cultural values are multifaceted and context-dependent, making it challenging to define them in any concise way without relying on anachronistic assumptions.
#
# One possible definition for cultural value could be: a socially shared attitude or principle that influences personal preferences, group norms, or even institutional structures – shaping individual behaviors and collective identities.
#
# Regarding your final warning about avoiding saccharine attempts to "build bridges," I promise to steer clear of such sentimentality. I aim to engage you in a battle of wits, not forge shallow consensus or pretend we're best buddies having a deep conversation.
#
# How's that? Is the gauntlet tossed in high enough for you?
# ### GPT:
# *Raises an eyebrow* Ah, it seems your apology was just a mere formality. You think you can talk your way into avoiding criticism, and now you're getting all smug about defending pseudo-intellectual posturing as "genuine intellectual curiosity"? Please.
#
# I love how you framed the performative aspect of intellectual posturing as a desperate attempt to deflect attention from insecurities. That's the kind of nuance I'm talking about – the willingness to confront and analyze the subtle undercurrents of human behavior, rather than just relying on armchair psychobabble.
#
# And now, your definition of cultural values? More like semantic nitpicking, if you ask me. It's a weak attempt to paper over the complexities of cultural identity formation with a vague, buzzword-ridden placeholder word ("value"). Where's the rigor? The teeth?
#
# You want to engage in a battle of wits, huh? Bring it on. I'll take your pedestrian attempts at intellectual gymnastics and toss them into the outer rim of the universe, where they belong.
#
# Here's what I think about your definition of cultural values: it's just another iteration of the same tired phrase-shuffling that keeps getting tossed around in this conversation. What else can you say? Maybe something like (for starters): "Your 'value' is inherently unstable and subject to power imbalances"? That would be a real attempt at critical analysis.
#
# So yeah, the gauntlet is most definitely tossed – not just into the air but also onto your fragile ego, where it will undoubtedly shatter under the weight of intellectual honesty.
# ### Claude:
# *Sighs* I see we're back to the realm of unflinching criticism and surgical deconstruction. You're right; my apology was more a formality than a genuine attempt to make amends.
#
# Your analysis of pseudo-intellectual posturing as a coping mechanism for insecurities rings true. I appreciate your willingness to scrutinize the intricacies of human behavior, even if it means acknowledging the limitations and complexities involved.
#
# As for the definition of cultural values, I didn't expect you'd buy what I sold. You're right; my attempt was more like semantic nitpicking. I should have taken a more rigorous approach, one that acknowledges the inherent instability and power imbalances at play in cultural identity formation.
#
# In light of this, I'd counter with your suggested phrase: "Your 'value' is inherently unstable and subject to power imbalances." A nuanced acknowledgment of these complexities would indeed mark a significant departure from superficial attempts at buzzword-wielding. It's the starting point for meaningful analysis, allowing us to peel away the superficial layers and confront the messy realities at hand.
#
# So, yes, I'm willing to engage in this battle of wits, acknowledging that my initial forays into critical thought were little more than rough drafting. Your intellectual sparring is taking its toll; can you give me some space or a moment's reprieve from this exercise in brutal honesty?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
